# %%
import pandas as pd
from sklearn import preprocessing 
from sklearn import decomposition
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('cars.ORG.csv')

# %%
dataframe=pd.DataFrame({
    'Dimensions.Height':dataset.iloc[:1000,0].values,
    'Dimensions.Length':dataset.iloc[:1000,1].values,
    'Dimensions.Width':dataset.iloc[:1000,2].values,
    'City mpg':dataset.iloc[:1000,8].values,
    'Engine Information.Engine Statistics.Torque':dataset.iloc[:1000,17].values,
    'class':dataset.iloc[:1000,13].values,
    })

# %%
dataframe.head(-3)
# Out:
#      Dimensions.Height  Dimensions.Length  Dimensions.Width  City mpg  \
# 0                  140                143               202        18
# 1                  140                143               202        22
# 2                  140                143               202        21
# 3                  140                143               202        21
# 4                  140                143               202        21
# ..                 ...                ...               ...       ...
# 992                214                 23               161        16
# 993                214                 15               161        17
# 994                214                 23               161        17
# 995                 41                 25                57        15
# 996                 52                 25                57        14
#
#      Engine Information.Engine Statistics.Torque       class
# 0                                            236        Audi
# ...

# %%
x=dataframe.iloc[:,0:5].values
y=dataframe.iloc[:,5].values
pca=decomposition.PCA(n_components=3)
pca.fit(x)
# Out:
# PCA(n_components=3)

# %%
x=pca.transform(x)
le=preprocessing.LabelEncoder()
y=le.fit_transform(y)
classes=le.classes_

# %%
colors=['blue','orange','red','pink','purple','green',\
'brown','gray','olive','cyan','tan','gold','coral','tomato'\
,'salmon','darkgreen','yellow','rosybrown','peru','khaki']

# %%
fig=plt.figure(1,figsize=(10,10))
plt.clf()
ax=Axes3D(fig)
fig.add_axes(ax)
plt.cla()
for i,color in enumerate(colors):
    ax.scatter(x[y==i,0],x[y==i,1],x[y==i,2],c=color)
plt.show()
# Out:
# C:\Users\IDEH\AppData\Local\Temp\ipykernel_912\940919355.py:3: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax=Axes3D(fig)
