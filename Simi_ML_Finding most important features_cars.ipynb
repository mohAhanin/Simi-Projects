# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot

# %%
df=pd.DataFrame(data=pd.read_csv('cars.ORG.csv'))
df.head(-3)
# Out:
#       Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                   140                143               202
# 1                   140                143               202
# 2                   140                143               202
# 3                   140                143               202
# 4                   140                143               202
# ...                 ...                ...               ...
# 5068                  3                253               201
# 5069                  3                253               201
# 5070                  3                253               201
# 5071                 13                253               201
# 5072                141                249               108
#
#      Engine Information.Driveline  \
# 0                 All-wheel drive
# 1               Front-wheel drive
# 2               Front-wheel drive
# 3                 All-wheel drive
# 4                 All-wheel drive
# ...

# %%
df_new=df[['Dimensions.Height','Dimensions.Length','Dimensions.Width','Engine Information.Number of Forward Gears',
          'Fuel Information.City mpg','Engine Information.Engine Statistics.Horsepower','Identification.Make']]

# %%
df_new
# Out:
#       Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                   140                143               202
# 1                   140                143               202
# 2                   140                143               202
# 3                   140                143               202
# 4                   140                143               202
# ...                 ...                ...               ...
# 5071                 13                253               201
# 5072                141                249               108
# 5073                160                249               108
# 5074                200                210               110
# 5075                200                 94               110
#
#       Engine Information.Number of Forward Gears  Fuel Information.City mpg  \
# 0                                              6                         18
# 1                                              6                         22
# ...

# %%
x=df_new.drop('Identification.Make',axis=1)
x
# Out:
#       Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                   140                143               202
# 1                   140                143               202
# 2                   140                143               202
# 3                   140                143               202
# 4                   140                143               202
# ...                 ...                ...               ...
# 5071                 13                253               201
# 5072                141                249               108
# 5073                160                249               108
# 5074                200                210               110
# 5075                200                 94               110
#
#       Engine Information.Number of Forward Gears  Fuel Information.City mpg  \
# 0                                              6                         18
# 1                                              6                         22
# ...

# %%
y=df_new['Identification.Make']
y
# Out:
# 0              Audi
# 1              Audi
# 2              Audi
# 3              Audi
# 4              Audi
#            ...
# 5071          Honda
# 5072    Lamborghini
# 5073    Lamborghini
# 5074            BMW
# 5075            BMW
# Name: Identification.Make, Length: 5076, dtype: object

# %%
df_new.columns
# Out:
# Index(['Dimensions.Height', 'Dimensions.Length', 'Dimensions.Width',
#        'Engine Information.Number of Forward Gears',
#        'Fuel Information.City mpg',
#        'Engine Information.Engine Statistics.Horsepower',
#        'Identification.Make'],
#       dtype='object')

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model=RandomForestClassifier(n_estimators=100)

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3)

# %%
model.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier()

# %%
print(model.feature_importances_)
# Out:
# [0.19805427 0.20104245 0.23433677 0.05977568 0.11046395 0.19632688]

# %%
# feature_importances=pd.Series(model.feature_importances_,index=df_new.columns)\
#                       .sort_values(ascending=False)

# %%
# get importance
importance = model.feature_importances_
# summarize feature importance
for i,v in enumerate(importance):
    print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()
# Out:
# Feature: 0, Score: 0.19805
# Feature: 1, Score: 0.20104
# Feature: 2, Score: 0.23434
# Feature: 3, Score: 0.05978
# Feature: 4, Score: 0.11046
# Feature: 5, Score: 0.19633
